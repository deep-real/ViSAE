# %%
from dictionary_learning import AutoEncoder, JumpReluAutoEncoder
from dictionary_learning.utils import load_dictionary


path = '/data/nvme2/yanlin/Checkpoints/SAE/Openai-CLIP-ViT-B-32_768/DictionaryLearning/JumpReLU/trainer_0'
ae, config = load_dictionary(path, 'cpu')
ae.W_dec.shape
# Out:
# torch.Size([1536, 768])
